# %% [markdown]
# ### Part 2: Named Entity Recognition (NER)

# %%
import pandas as pd
import nltk
import re

# %%
import spacy
from spacy import displacy

# %%
import numpy as np
import pycountry as pc
import ast
from ast import literal_eval

# %%
from collections import defaultdict

# %% [markdown]
# Loaded spacy for NER.

# %%
ner = spacy.load("en_core_web_sm")

# %%
all_books = pd.read_csv('../librivox_df')

# %% [markdown]
# #### Step 1: Filtered all English language books for NER

# %%
books_en = all_books[all_books['Language'] == 'English']

# %% [markdown]
# Note: Used Transcripts of The Great Gatsby for displacy.

# %%
gatsby = books_en['Transcripts'].iloc[147]

# %%
gatsby1 = ner(gatsby)

# %%
displacy.render(gatsby1,style="ent",jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     x.org
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Great Gatsby
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     F Scott Fitzgerald
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chapter 1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LAW</span>
# </mark>
# . In my younger and more vulnerable years, my father gave me some advice that I've been turning over in my mind ever since. Whenever you feel like criticizing anyone, he told me, just remember that all the people in this world haven't had the advantages that you've had. He didn't say any more, but we've always been unusually communicative in a reserved way, and I understood that he meant a great deal more than that. In consequence, I'm inclined to reserve all judgments. I habit that has opened up many curious natures to me, and also made me the victim of not a few veteran wars. The abnormal mind is quick to detect and attach itself to this quality when it appears in a normal person, and so it came about that in college I was unjustly accused of being a politician, because I was privy to the secret griefs of wild, unknown men. Most of the confidence were unsought. Frequently I have fain's sleep, preoccupation, or a hostile levity when I realized by some unmistakable sign that an intimate revelation was quivering on the horizon. For the intimate revelations of young men, or at least the terms in which they express them are usually plagiaristic and mired by obvious suppressions. Reserving judgments is a matter of infinite hope. I am still a little afraid of missing something if I forget that, as my father
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     snobbishly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  suggested, and I
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     snobbishly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  repeat, a sense of the fundamental decencies is parceled out unequally at birth. And after boasting this way of my tolerance, I come to the admission that it has a limit. Conduct may be founded on the hard rock or the wet marshes, but after a certain point I don't care what it's founded on. When I came back from the east,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last autumn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , I felt that I wanted the world to be in uniform, and at a sort of moral attention forever. I wanted no more riotous excursions with privileged glimpses into the human heart.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Only Gatsby
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , the man who gives his name to this book, was exempt from my reaction. Gatsby, who represented everything for which I have an unaffected scorn. If personality is an unbroken series of successful gestures, then there was something gorgeous about him, some heightened sensitivity to the promises of life, as if he were related to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of those intricate machines that register earthquakes
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10,000 miles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  away. This responsiveness had nothing to do with that flabby impressionability which is dignified under the name of the creative temperament. It was an extraordinary gift for hope. A romantic readiness, such as I have never found in any other person, and which it is not likely I shall ever find again. No. Gatsby turned out all right at the end. It is what preyed on
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gatsby
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . What foul dust floated in the wake of his dreams, that temporarily closed out my interest in the abortive sorrows and short-winded elations of men. My family have been prominent well to do people in this middle western city for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     three
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  generations. The caroways are something of a clan, and we have a tradition that we are descended from the dukes of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Buckloy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . But the actual founder of my line was my grandfather's brother, who came here in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     51
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , sent a substitute to
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Civil War
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
# , and started the whole sail hardware business that my father carries on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [418], in <cell line: 1>()
# ----> 1 displacy.render(gatsby1,style="ent",jupyter=True)[:500]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
books_en
# Out:
#      ID                                              Title  \
# 1     1                                  The Book of Enoch
# 3     3  The Meditations of the Emperor Marcus Aurelius...
# 4     4                                       Three Things
# 6     6  Biographical Memoir of John Wesley Powell, 183...
# 8     8  True Stories of Crime from the District Attorn...
# ..   ..                                                ...
# 368  68                      Doctor Rabbit and Tom Wildcat
# 370  70  Dramatic Reading Scene and Story Collection, V...
# 372  72  The Mormon Battalion, Its History and Achievem...
# 373  73                                   Dogs and Puppies
# 374  74              Short Ghost and Horror Collection 061
#
#                        Author   Views  Favorites      Date_uploaded  \
# 1                     Unknown  155927      102.0   December 9, 2018
# 3             Marcus Aurelius  302755       58.0    January 2, 2018
# 4         Ella Wheeler Wilcox  516824        7.0       July 1, 2018
# 6        William Morris Davis  402442        4.0      March 2, 2018
# 8         Arthur Cheney Train  364346       17.0    August 16, 2018
# ..                        ...     ...        ...                ...
# 368       Thomas Clark Hinkle   10073        1.0   November 9, 2022
# 370                   Various   56821        2.0     April 30, 2022
# 372             B. H. Roberts   29381        1.0   November 4, 2022
# 373  Frances Trego Montgomery   32539        2.0  November 10, 2022
# 374                   Various   51160        2.0     August 6, 2022
#
#                                                Reviews  Reviews_n  \
# 1    ['\n        I enjoyed this recording very much...          1
# 3    ['\n        I recently discovered this gem of ...          1
# 4                                                   []          0
# 6                                                   []          0
# 8                                                   []          0
# ..                                                 ...        ...
# 368                                                 []          0
# 370                                                 []          0
# 372  ['\n        If you are someone who is really f...          1
# 373                                                 []          0
# 374                                                 []          0
#
#                                            Transcripts  \
# 1    r, please visit Librevox.org. Section 1. Edito...
# 3    ation or to volunteer, please visit Librevox.o...
# 4    gs there are, eternal in their worth. Love tha...
# 6    n or to volunteer, please visit Librevox.org. ...
# 8    tion or to volunteer, please visit Librevox.or...
# ..                                                 ...
# 368  isit Lieberbox.org. Read by Laura. Dr. Rabbit ...
# 370  ng, all Librevox recordings are in the public ...
# 372  to volunteer, please visit Libravox.org. Read ...
# 373  riVox.org. Read by Prajakta. Docs and Puppets ...
# 374  sit LibraVox.org. Read by Dale Growthman. Mary...
#
#                                                  Genre Language   Runtime  \
# 1                                             Religion  English  04:28:56
# 3    Classics (Greek & Latin Antiquity), Biography ...  English  04:47:46
# 4        Multi-version (Weekly and Fortnightly poetry)  English  00:12:59
# 6                            Biography & Autobiography  English  03:40:51
# 8                                           True Crime  English  06:49:50
# ..                                                 ...      ...       ...
# 368     Animals & Nature, Myths, Legends & Fairy Tales  English  01:22:37
# 370                                  Dramatic Readings  English  03:17:50
# 372                            War & Military, History  English  02:51:09
# 373                                 Action & Adventure  English  00:51:56
# 374                      Horror & Supernatural Fiction  English  08:05:07
#
#                      Narrated_by
# 1                      CJ Plogue
# 3            LibriVox Volunteers
# 4            LibriVox Volunteers
# 6    Melanie Schleeter McCalmont
# 8                Colleen McMahon
# ..                           ...
# 368                 Laurie Banza
# 370          LibriVox Volunteers
# 372                  Wayne Cooke
# 373          LibriVox Volunteers
# 374          LibriVox Volunteers
#
# [241 rows x 13 columns]

# %% [markdown]
# #### Step 1 : Obtained NER labels for all English books.
# Focus is on 'GPE', 'LOC', 'NORP', 'PERSON' labels for now.

# %%
def nerList(text):
    doc = ner(text)
    d = defaultdict(list)
    all_labels = ['GPE', 'LOC', 'NORP', 'PERSON']
    for word in doc.ents:
        if word.label_ in all_labels:
            d[word.label_].append(word.text)
    for k,v in d.items():
        m = set(i for i in v) #if v.count(i) > 1)
        d[k] = list(m)
    
    return d

# %%
books_d = books_en['Transcripts'].apply(nerList)

# %%
df = pd.DataFrame(list(books_d))

# %%
ner_df = df.replace(np.nan, '[]', regex=True)

# %%
ner_df = pd.read_csv('../ner_df')

# %%
ner_df.head(20)
# Out:
#                                                  NORP  \
# 0   ['Hebrew', 'Jewish', 'Greek', 'Christian', 'po...
# 1                                       ['Platonist']
# 2                                                  []
# 3                                  ['Greek', 'Latin']
# 4                               ['Dutch', 'American']
# 5                                                  []
# 6                                                  []
# 7                              ['Maltese', 'African']
# 8   ['Thibian', 'Ejipteri', 'Alizian', 'English', ...
# 9                            ['French', 'metropolis']
# 10  ['British', 'betnese', 'Indians', 'German', 'S...
# 11                                                 []
# 12                                                 []
# 13  ['Russian', 'Greek', 'Australian', 'Latin', 'I...
# 14       ['Gothic', 'Costican', 'Dutch', 'Christian']
# 15                                                 []
# 16               ['Old Egyptian', 'American', 'Arab']
# 17                                                 []
# 18                                                 []
# 19                                                 []
#
#                                                PERSON  \
# 0   ['Canon Charles', 'John Herkiness', 'Jubilee',...
# 1   ['Alexander the Gremarian', 'Maximus', 'Tuskeu...
# 2                                                  []
# 3   ['William Morris Davis', 'John Wesley Powell',...
# 4   ['P. Body', 'Gang', 'forgeri', 'Prentice Parke...
# 5                                             ['jaw']
# 6   ['Keef', 'Kurt Keef', 'Dan', 'Sikamoor Hight',...
# 7   ['Etna', 'Dobel', 'Ambrose Pierce', 'Dale Grow...
# 8   ['Nil', 'Patrick Sivil', 'Edward Maud Thompson...
# 9   ['Martin', 'Nory', 'Horus', 'Simpson', 'Lannig...
# 10  ['Jane Turrell', "Ebenezer Bert's", 'Pius', 'w...
# 11  ['Chil-cut', 'Chil', 'Wilson', 'Devora Allen',...
# 12  ['Mark Smith', 'Folio', 'Paul La Parille', 'Wi...
# 13  ['Margorn', 'James Polledore', 'Mrs', 'James P...
# 14  ['Fow', 'Scrooge', 'Mark me', 'Said Scrooge', ...
# 15  ['Zames Khrin', 'Ridgeway', 'Joseph Tabler', '...
# 16  ['Burton', "Linda O'Senfaitak", 'Lene', 'Lins'...
# 17  ['moon', 'Ting', 'Manied', 'Hayoki', 'Poof', '...
# 18  ['Greg Jerdano', 'Sally Blushton', 'sun', 'Bob...
# 19  ['Nathaniel C. Faller Jr. Preface', 'Larry Wil...
#
#                                                   GPE  \
# 0   ['Erimich', 'c.p', 'Jordan', 'Palestine', 'Gal...
# 1         ['Relious', 'Epilonia', 'Greece', 'Marcus']
# 2                                                  []
# 3   ['Ohio', 'Malaska', 'Illinois', 'the United St...
# 4   ['St. Louis', 'West 38th Street', 'St. Paul', ...
# 5                       ['Tolstry', 'Nima', 'Bulkka']
# 6   ['Texas', 'Miss.', 'Boston', 'Baylem', 'Tattle...
# 7   ['mizzon', 'Malta', 'Naples', 'Italy', 'Chicago']
# 8   ['Nebcad', 'Missiers', 'Nathleris', 'Les', 'Tu...
# 9   ['Foguri', 'Fogretis', 'quay', 'Magna Carta', ...
# 10  ['Boston', 'Brooklyn', 'England', 'Maira', 'Co...
# 11     ['Urgophobia', 'England', 'America', 'London']
# 12  ['Austria', 'Amsterdam', 'France', 'Rishilu', ...
# 13  ['London', 'Richmond', 'Israel', 'Scotland', '...
# 14  ['London', "St. Paul's", 'Savannah Georgia', '...
# 15                                        ['Oncelle']
# 16               ['New York', 'Queer', 'Los Angeles']
# 17                               ['Enia', 'Elevagar']
# 18           ['Florida', 'Newport Richie', 'Jericho']
# 19                                                 []
#
#                                                   LOC
# 0   ['Northern Palestine', 'the Accursed Valley', ...
# 1                                                  []
# 2                                                  []
# 3               ['the Genesee Valley', 'Mississippi']
# 4                                  ['the Bay window']
# 5                                          ['Bulkka']
# 6                                                  []
# 7                                                  []
# 8                                    ['Heliopolitan']
# 9                                                  []
# 10                          ['Europe', 'New England']
# 11                                                 []
# 12                                                 []
# 13                                                 []
# 14                                                 []
# 15                                                 []
# 16                                                 []
# 17                                                 []
# 18                                           ['east']
# 19                                                 []

# %% [markdown]
# #### Step 2: Extracting Features from GPE Column.
# GPE stands for Geo-Political Entity, and this includes Politically accepted entities, like Country, City, States. Using these features, we determined how many countries are mentioned in the text and which country is mentioned the most.

# %%
## Extracting list from inside the string in every row.

# %%
gpe = ner_df['GPE'].apply(lambda x: literal_eval(str(x)))

# %%
def country_name_check(input_list):
    pc_list = list(pc.countries)
    names = []
    for i in pc_list:
        names.append(i.name)
        ## if any part of x in input list is in names
    
    country = []
    for j in input_list:
        if j in names: #any(js in j for js in pc_list):
            country.append(j)
    return country

# %%
# list of all country names appearing in each book
gpe_countries = gpe.apply(country_name_check).rename('countries')
gpe_countries.head(3)
# Out:
# 0    [Jordan, Israel]
# 1            [Greece]
# 2                  []
# Name: countries, dtype: object

# %%
gpe_countries_n = gpe_countries.apply(len)

# %%
unique = set(x for l in list(gpe_countries) for x in l)

# %%
rem_ = ['the United States Department', 'the United States Forest Service', 'the United States Review', 'State United States of America'
       , 'Dick Chadwick', 'the Jersey Shore', 'Savannah Georgia', 'South Australia', 'Malice', 'Bologna Italy', 'Old Ireland']

# %%
## set of all unique country names appearing in all books
unique_countries = unique - set(rem_)
unique_countries
# Out:
# {'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Bahamas',
#  'Belgium',
#  'Brazil',
#  'Canada',
#  'China',
#  'Denmark',
#  'Egypt',
#  'Ethiopia',
#  'France',
#  'Georgia',
#  'Germany',
#  'Greece',
#  'Hong Kong',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Japan',
#  'Jordan',
#  'Libya',
#  'Lithuania',
#  'Luxembourg',
#  'Malaysia',
#  'Malta',
#  'Mexico',
#  'New Zealand',
#  'Norway',
#  'Poland',
#  'Portugal',
#  'Romania',
#  'Serbia',
#  'South Africa',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'Turkey',
#  'Uganda',
#  'United States'}

# %%
countries_n = []
for i in gpe_countries:
    c = 0
    for j in i:
        
        if j in unique_countries:
            c+=1
    countries_n.append(c)

# %%
countries_n = pd.Series(countries_n)

# %%
from urllib.request import urlopen
import json

# %%
def get_key(val):
    for key, value in dict(states).items():
        if val in value:
            return key

# %% [markdown]
# #### JSON data of all countries, their capitals, states and other details
# Using this data, state and capital names that appeared in the books were determined and also, to which countries they belong.

# %%
js = 'https://raw.githubusercontent.com/dr5hn/countries-states-cities-database/master/countries%2Bstates.json'
response = urlopen(js)
data_json = json.loads(response.read())

# %%
states = defaultdict(list)
for c in data_json:
    for i in c['states']:
        states[c['name']].append(i['name'])

# %%
# country from states
def countryFromStates(L):
    countries = []
    for i in L:
        for v in states.values():
            if i in v:
                countries.append(get_key(i))
    return countries

# %%
c_states = gpe.apply(countryFromStates).rename('c_states')

# %%
capitals = {}
for country in data_json:
    #for k,v in country.items():
    capitals[country['capital']] = country['name']

# %%
# country from capital
def countryFromCapitals(L):
    countries = []
    for i in L:
        if i in capitals.keys():
            countries.append(capitals[i])
    return countries

# %%
c_caps = gpe.apply(countryFromCapitals).rename('c_caps')

# %%
all_countries = c_caps+c_states+gpe_countries

# %%
## frequency of all countries mentioned (by name or through capital/states)
all_countries.explode().value_counts()
# Out:
# United States                     133
# United Kingdom                     94
# France                             62
# Austria                            21
# Italy                              18
# Germany                            17
# Israel                             11
# China                              11
# Spain                              11
# Australia                          11
# Egypt                              10
# Russia                              8
# Canada                              8
# Belgium                             7
# Hungary                             7
# Palestinian Territory Occupied      7
# Japan                               6
# Greece                              6
# Poland                              5
# Georgia                             4
# Switzerland                         4
# Jordan                              4
# Portugal                            3
# India                               3
# New Zealand                         3
# Luxembourg                          2
# Syria                               2
# South Africa                        2
# Denmark                             2
# Ireland                             2
# Brazil                              2
# Czech Republic                      2
# Iraq                                2
# Nicaragua                           2
# Netherlands                         2
# Turkey                              1
# Norfolk Island                      1
# Argentina                           1
# Serbia                              1
# Norway                              1
# Ethiopia                            1
# Malaysia                            1
# Bahamas                             1
# Mexico                              1
# Uganda                              1
# Hong Kong S.A.R.                    1
# Romania                             1
# Sweden                              1
# Lithuania                           1
# Iceland                             1
# Libya                               1
# Hong Kong                           1
# Antigua And Barbuda                 1
# Guyana                              1
# Ghana                               1
# Philippines                         1
# Malta                               1
# Armenia                             1
# dtype: int64

# %%
## getting unique values
def getUnique(L):
    U = []
    for i in L:
        i = list(set(i))
        U.append(i)
    return U

# %%
u_per_row = pd.Series(getUnique(all_countries))

# %%
## number of times a country appears in each book
u_per_row.explode().value_counts()
# Out:
# United States                     69
# United Kingdom                    63
# France                            40
# Italy                             14
# Germany                           14
# Austria                           11
# China                             11
# Egypt                             10
# Australia                         10
# Spain                              9
# Israel                             8
# Greece                             6
# Palestinian Territory Occupied     6
# Poland                             5
# Canada                             5
# Hungary                            5
# Russia                             4
# Belgium                            4
# Switzerland                        4
# Georgia                            4
# Jordan                             4
# New Zealand                        3
# India                              3
# Japan                              3
# Brazil                             2
# South Africa                       2
# Ireland                            2
# Czech Republic                     2
# Netherlands                        2
# Denmark                            2
# Uganda                             1
# Syria                              1
# Malaysia                           1
# Ethiopia                           1
# Armenia                            1
# Argentina                          1
# Bahamas                            1
# Turkey                             1
# Romania                            1
# Norfolk Island                     1
# Serbia                             1
# Norway                             1
# Hong Kong S.A.R.                   1
# Sweden                             1
# Luxembourg                         1
# Lithuania                          1
# Portugal                           1
# Iceland                            1
# Libya                              1
# Hong Kong                          1
# Antigua And Barbuda                1
# Guyana                             1
# Iraq                               1
# Ghana                              1
# Nicaragua                          1
# Philippines                        1
# Malta                              1
# Mexico                             1
# dtype: int64

# %%
## dummy column for books that mention US and books that don't
US_d = u_per_row.isin(['United States']).astype('int')

# %%
## number of states mentioned in each book
states_n = c_states.apply(len)

# %%
## number of unique countries (including their states and capitals) mentioned in each book
all_countries_n = u_per_row.apply(len)

# %% [markdown]
# #### Step3: Sorting the names from PERSON column
# The PERSON label contained all entities with names of Characters (with a few words that were assigned this label through error). These were sorted manually into male, female and neutral (for the mistaken words) using excel. (Excel file attached) This was used to determine how many male and female characters each book contained.

# %%
names_sorted = pd.read_excel('../Sorted_names.xlsx')

# %%
names_sorted.head(5)
# Out:
#        Names Gender
# 0      Mill'      F
# 1   Chaucer'      M
# 2  W. Meyer'      M
# 3      Moon'      N
# 4   Bad DaM'      N

# %%
from string import whitespace

# %%
def cleanNames(L):
    New = []
    for i in L:
        k = i.strip(whitespace + '"\'')
        New.append(k)
    return New

# %%
names_sorted['clean_names'] = cleanNames(names_sorted['Names'])  #.apply(cleanNames)

# %%
female_names = list(names_sorted[names_sorted['Gender'] == 'F']['clean_names'])
male_names = list(names_sorted[names_sorted['Gender'] == 'M']['clean_names'])
neutral_names = list(names_sorted[names_sorted['Gender'] == 'N']['clean_names'])

# %%
characters = ner_df['PERSON'].apply(lambda x: literal_eval(str(x)))

# %%
characters
# Out:
# 0      [Canon Charles, John Herkiness, Jubilee, Moon,...
# 1      [Alexander the Gremarian, Maximus, Tuskeulum, ...
# 2                                                     []
# 3      [William Morris Davis, John Wesley Powell, Cri...
# 4      [P. Body, Gang, forgeri, Prentice Parker Singl...
#                              ...
# 236    [Rose Chickenhouse, Hurry, Laura, Tom Wildcat,...
# 237    [Ferdinand DeVero, Count Adelaan, Samuel Pickw...
# 238    [Alexander W. Donafin, Saldo, Cook, Wayne Cook...
# 239    [Jip Seeds, Buster, Fritz, Jip Seed, Francis T...
# 240    [Cuberly, Grandpa, Cubrely, Poole, Hortell, cu...
# Name: PERSON, Length: 241, dtype: object

# %%
# def assignGender(L):
#     G = []
#     for i in L:
#         temp = []
#         for j in i:
#             if j in male_names:
#                 temp.append('M')
#             if j in female_names:
#                 temp.append('F')
#             else:
#                 temp.append('N')
#         G.append(temp)
#     return G

# %%
def genderFrequency(L1, L2):
    freq = []
    for i in L1:
        c = 0
        for j in i:
            if j in L2:
                c+=1
        freq.append(c)
    return freq

# %%
male_n = pd.Series(genderFrequency(characters,male_names))
female_n = pd.Series(genderFrequency(characters,female_names))
neutral_n = pd.Series(genderFrequency(characters,neutral_names))

# %%
Person_df = pd.concat([male_n,female_n,neutral_n],axis=1).rename(columns = {0:'male_n',1:'female_n',2:'neutral_n'})

# %%
Person_df
# Out:
#      male_n  female_n  neutral_n
# 0         4         0          3
# 1         0         0          0
# 2         0         0          0
# 3         1         0          0
# 4         4         2          1
# ..      ...       ...        ...
# 236       1         2          1
# 237       6         1          0
# 238       7         1          1
# 239       5         1          0
# 240      20         6          3
#
# [241 rows x 3 columns]

# %% [markdown]
# #### Step4: Get all NER Processed columns

# %%
countries_n
# Out:
# 0      2
# 1      1
# 2      0
# 3      0
# 4      0
#       ..
# 236    0
# 237    0
# 238    2
# 239    0
# 240    0
# Length: 241, dtype: int64

# %%
all_ner = pd.concat([ner_df, countries_n, states_n,all_countries_n,US_d,Person_df]
                    ,axis =1).rename(columns={'c_states':'states_n',0:'countries_n',1:'all_countries_n', 2:'US_d'})

# %%
all_ner
# Out:
#                                                   NORP  \
# 0    ['Hebrew', 'Jewish', 'Greek', 'Christian', 'po...
# 1                                        ['Platonist']
# 2                                                   []
# 3                                   ['Greek', 'Latin']
# 4                                ['Dutch', 'American']
# ..                                                 ...
# 236                                                 []
# 237                                        ['English']
# 238  ['Greek', 'American', 'Zedafans', 'Persians', ...
# 239                                         ['French']
# 240                                          ['Crian']
#
#                                                 PERSON  \
# 0    ['Canon Charles', 'John Herkiness', 'Jubilee',...
# 1    ['Alexander the Gremarian', 'Maximus', 'Tuskeu...
# 2                                                   []
# 3    ['William Morris Davis', 'John Wesley Powell',...
# 4    ['P. Body', 'Gang', 'forgeri', 'Prentice Parke...
# ..                                                 ...
# 236  ['Rose Chickenhouse', 'Hurry', 'Laura', 'Tom W...
# 237  ['Ferdinand DeVero', 'Count Adelaan', 'Samuel ...
# 238  ['Alexander W. Donafin', 'Saldo', 'Cook', 'Way...
# 239  ['Jip Seeds', 'Buster', 'Fritz', 'Jip Seed', '...
# 240  ['Cuberly', 'Grandpa', 'Cubrely', 'Poole', 'Ho...
#
#                                                    GPE  \
# 0    ['Erimich', 'c.p', 'Jordan', 'Palestine', 'Gal...
# 1          ['Relious', 'Epilonia', 'Greece', 'Marcus']
# 2                                                   []
# 3    ['Ohio', 'Malaska', 'Illinois', 'the United St...
# 4    ['St. Louis', 'West 38th Street', 'St. Paul', ...
# ..                                                 ...
# 236                                                 []
# 237       ['Gowland', 'Librevox', 'Persona', 'Veyola']
# 238  ['El Paso', 'Tigris', 'Zedafans', 'Mexico', 'M...
# 239                                        ['Puppets']
# 240       ['MD', 'Shala', 'Ganyme', 'Simon', 'Thuzzy']
#
#                                                    LOC  countries_n  states_n  \
# 0    ['Northern Palestine', 'the Accursed Valley', ...            2         1
# 1                                                   []            1         0
# 2                                                   []            0         0
# 3                ['the Genesee Valley', 'Mississippi']            0         4
# 4                                   ['the Bay window']            0         2
# ..                                                 ...          ...       ...
# 236                                                 []            0         0
# 237                                                 []            0         0
# 238  ['the Gulf of Mexico', 'the Pacific Ocean', 'M...            2         1
# 239                                         ['Europe']            0         0
# 240                                           ['Mars']            0         0
#
#      all_countries_n  US_d  male_n  female_n  neutral_n
# 0                  3     0       4         0          3
# 1                  1     0       0         0          0
# 2                  0     0       0         0          0
# 3                  1     0       1         0          0
# 4                  1     0       4         2          1
# ..               ...   ...     ...       ...        ...
# 236                0     0       1         2          1
# 237                0     0       6         1          0
# 238                3     0       7         1          1
# 239                0     0       5         1          0
# 240                0     0      20         6          3
#
# [241 rows x 11 columns]

# %%
books = books_en.reset_index().drop('ID', axis = 1)

# %%
en_books_df = pd.concat([books, all_ner], axis = 1).drop('index', axis = 1)

# %% [markdown]
# #### Table to be used for Features Extraction

# %%
en_books_df
# Out:
#                                                  Title  \
# 0                                    The Book of Enoch
# 1    The Meditations of the Emperor Marcus Aurelius...
# 2                                         Three Things
# 3    Biographical Memoir of John Wesley Powell, 183...
# 4    True Stories of Crime from the District Attorn...
# ..                                                 ...
# 236                      Doctor Rabbit and Tom Wildcat
# 237  Dramatic Reading Scene and Story Collection, V...
# 238  The Mormon Battalion, Its History and Achievem...
# 239                                   Dogs and Puppies
# 240              Short Ghost and Horror Collection 061
#
#                        Author   Views  Favorites      Date_uploaded  \
# 0                     Unknown  155927      102.0   December 9, 2018
# 1             Marcus Aurelius  302755       58.0    January 2, 2018
# 2         Ella Wheeler Wilcox  516824        7.0       July 1, 2018
# 3        William Morris Davis  402442        4.0      March 2, 2018
# 4         Arthur Cheney Train  364346       17.0    August 16, 2018
# ..                        ...     ...        ...                ...
# 236       Thomas Clark Hinkle   10073        1.0   November 9, 2022
# 237                   Various   56821        2.0     April 30, 2022
# 238             B. H. Roberts   29381        1.0   November 4, 2022
# 239  Frances Trego Montgomery   32539        2.0  November 10, 2022
# 240                   Various   51160        2.0     August 6, 2022
#
#                                                Reviews  Reviews_n  \
# 0    ['\n        I enjoyed this recording very much...          1
# 1    ['\n        I recently discovered this gem of ...          1
# 2                                                   []          0
# 3                                                   []          0
# 4                                                   []          0
# ..                                                 ...        ...
# 236                                                 []          0
# 237                                                 []          0
# 238  ['\n        If you are someone who is really f...          1
# 239                                                 []          0
# 240                                                 []          0
#
#                                            Transcripts  \
# 0    r, please visit Librevox.org. Section 1. Edito...
# 1    ation or to volunteer, please visit Librevox.o...
# 2    gs there are, eternal in their worth. Love tha...
# 3    n or to volunteer, please visit Librevox.org. ...
# 4    tion or to volunteer, please visit Librevox.or...
# ..                                                 ...
# 236  isit Lieberbox.org. Read by Laura. Dr. Rabbit ...
# 237  ng, all Librevox recordings are in the public ...
# 238  to volunteer, please visit Libravox.org. Read ...
# 239  riVox.org. Read by Prajakta. Docs and Puppets ...
# 240  sit LibraVox.org. Read by Dale Growthman. Mary...
#
#                                                  Genre Language  ...  \
# 0                                             Religion  English  ...
# 1    Classics (Greek & Latin Antiquity), Biography ...  English  ...
# 2        Multi-version (Weekly and Fortnightly poetry)  English  ...
# 3                            Biography & Autobiography  English  ...
# 4                                           True Crime  English  ...
# ..                                                 ...      ...  ...
# 236     Animals & Nature, Myths, Legends & Fairy Tales  English  ...
# 237                                  Dramatic Readings  English  ...
# 238                            War & Military, History  English  ...
# 239                                 Action & Adventure  English  ...
# 240                      Horror & Supernatural Fiction  English  ...
#
#                                                 PERSON  \
# 0    ['Canon Charles', 'John Herkiness', 'Jubilee',...
# 1    ['Alexander the Gremarian', 'Maximus', 'Tuskeu...
# 2                                                   []
# 3    ['William Morris Davis', 'John Wesley Powell',...
# 4    ['P. Body', 'Gang', 'forgeri', 'Prentice Parke...
# ..                                                 ...
# 236  ['Rose Chickenhouse', 'Hurry', 'Laura', 'Tom W...
# 237  ['Ferdinand DeVero', 'Count Adelaan', 'Samuel ...
# 238  ['Alexander W. Donafin', 'Saldo', 'Cook', 'Way...
# 239  ['Jip Seeds', 'Buster', 'Fritz', 'Jip Seed', '...
# 240  ['Cuberly', 'Grandpa', 'Cubrely', 'Poole', 'Ho...
#
#                                                    GPE  \
# 0    ['Erimich', 'c.p', 'Jordan', 'Palestine', 'Gal...
# 1          ['Relious', 'Epilonia', 'Greece', 'Marcus']
# 2                                                   []
# 3    ['Ohio', 'Malaska', 'Illinois', 'the United St...
# 4    ['St. Louis', 'West 38th Street', 'St. Paul', ...
# ..                                                 ...
# 236                                                 []
# 237       ['Gowland', 'Librevox', 'Persona', 'Veyola']
# 238  ['El Paso', 'Tigris', 'Zedafans', 'Mexico', 'M...
# 239                                        ['Puppets']
# 240       ['MD', 'Shala', 'Ganyme', 'Simon', 'Thuzzy']
#
#                                                    LOC countries_n states_n  \
# 0    ['Northern Palestine', 'the Accursed Valley', ...           2        1
# 1                                                   []           1        0
# 2                                                   []           0        0
# 3                ['the Genesee Valley', 'Mississippi']           0        4
# 4                                   ['the Bay window']           0        2
# ..                                                 ...         ...      ...
# 236                                                 []           0        0
# 237                                                 []           0        0
# 238  ['the Gulf of Mexico', 'the Pacific Ocean', 'M...           2        1
# 239                                         ['Europe']           0        0
# 240                                           ['Mars']           0        0
#
#     all_countries_n  US_d  male_n  female_n  neutral_n
# 0                 3     0       4         0          3
# 1                 1     0       0         0          0
# 2                 0     0       0         0          0
# 3                 1     0       1         0          0
# 4                 1     0       4         2          1
# ..              ...   ...     ...       ...        ...
# 236               0     0       1         2          1
# 237               0     0       6         1          0
# 238               3     0       7         1          1
# 239               0     0       5         1          0
# 240               0     0      20         6          3
#
# [241 rows x 23 columns]

# %%
#en_books_df.to_csv('../en_books_df', index = False, header=True)
